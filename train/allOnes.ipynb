# %%
import pandas as pd
predict = pd.read_csv('./target/y_predict.csv')
predict
# Out:
#        wagnum       month
# 0       33361  2023-03-01
# 1       33364  2023-03-01
# 2       33366  2023-03-01
# 3       33358  2023-03-01
# 4       33349  2023-03-01
# ...       ...         ...
# 33702   17621  2023-03-01
# 33703   25045  2023-03-01
# 33704   27156  2023-03-01
# 33705   21361  2023-03-01
# 33706    8061  2023-03-01
#
# [33707 rows x 2 columns]

# %%
predict['target_month'] = len(predict) * [1]
predict['target_day'] = len(predict) * [1]
predict
# Out:
#        wagnum       month  target_month  target_day
# 0       33361  2023-03-01             1           1
# 1       33364  2023-03-01             1           1
# 2       33366  2023-03-01             1           1
# 3       33358  2023-03-01             1           1
# 4       33349  2023-03-01             1           1
# ...       ...         ...           ...         ...
# 33702   17621  2023-03-01             1           1
# 33703   25045  2023-03-01             1           1
# 33704   27156  2023-03-01             1           1
# 33705   21361  2023-03-01             1           1
# 33706    8061  2023-03-01             1           1
#
# [33707 rows x 4 columns]

# %%
predict.to_csv('allOnes.csv')
