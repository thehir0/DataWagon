# %%
import pandas as pd
true_target_path = pd.read_csv('./prediction/target_predicton.csv')
true_target_path
# Out:
#        wagnum  target_month  target_day
# 0       33361             0           0
# 1       33364             1           1
# 2       33366             1           1
# 3       33358             0           0
# 4       33349             0           0
# ...       ...           ...         ...
# 33972   25045             0           0
# 33973   27156             0           0
# 33974   21361             0           0
# 33975    8061             1           1
# 33976   33350             1           1
#
# [33977 rows x 3 columns]

# %%
target_path =  pd.DataFrame({'wagnum': true_target_path['wagnum'].to_list(), 'target_month':[1]*len(true_target_path), 'target_day':[1]*len(true_target_path)})
target_path.to_csv('allOnes.csv')
target_path
# Out:
#        wagnum  target_month  target_day
# 0       33361             1           1
# 1       33364             1           1
# 2       33366             1           1
# 3       33358             1           1
# 4       33349             1           1
# ...       ...           ...         ...
# 33972   25045             1           1
# 33973   27156             1           1
# 33974   21361             1           1
# 33975    8061             1           1
# 33976   33350             1           1
#
# [33977 rows x 3 columns]

# %%
from metrics_f1 import calc_f1_score
calc_f1_score('./prediction/target_predicton.csv', 'allZeros.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /Users/adautov/Desktop/DataWagon/train/allOnes.ipynb Cell 3 line 2
#       <a href='vscode-notebook-cell:/Users/adautov/Desktop/DataWagon/train/allOnes.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> from metrics_f1 import calc_f1_score
# ----> <a href='vscode-notebook-cell:/Users/adautov/Desktop/DataWagon/train/allOnes.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a> calc_f1_score('./prediction/target_predicton.csv', 'allZeros.csv')
#
# File ~/Desktop/DataWagon/train/metrics_f1.py:8, in calc_f1_score(test_url, prediction_url)
#       5 def calc_f1_score(test_url: str, prediction_url: str) -> float:
#       7     true_labels = pd.read_csv(test_url)
# ----> 8     pred_labels = pd.read_csv(prediction_url)
#       9     # Таргет для месячного прогноза
#      10     true_labels_month = true_labels['target_month'].values
#
# ...
